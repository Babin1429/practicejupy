# %%
import numpy as np

# %%
arr=np.array([1,2,3,4,5])
print(arr)
type(arr)
# Out:
# [1 2 3 4 5]
# numpy.ndarray

# %%
arr.ndim 
arr.shape
# Out:
# (5,)

# %%
arr2=np.array([[12,33,44],[3,2,6]])

# %%
arr2.ndim
# Out:
# 2

# %%
arr[1:4]
# Out:
# array([2, 3, 4])

# %%
np.mean(arr2,axis=1)
# Out:
# array([29.66666667,  3.66666667])

# %%
np.array(arr+5)
# Out:
# array([ 6,  7,  8,  9, 10])

# %%
np.array(arr/5)
# Out:
# array([0.2, 0.4, 0.6, 0.8, 1. ])

# %%
np.array(arr<3)
# Out:
# array([ True,  True, False, False, False])

# %%
np.dot(arr,3)
# Out:
# array([ 3,  6,  9, 12, 15])
